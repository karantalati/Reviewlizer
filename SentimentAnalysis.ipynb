# %%
from textblob import TextBlob

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Replace 'path/to/your/file.csv' with the actual file path of your CSV file
data = pd.read_csv('/content/drive/MyDrive/merge-csv.com.csv')

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt


data = pd.read_csv('/content/drive/MyDrive/merge-csv.com.csv')


data['Review'] = data['Review'].fillna('') 
data['sentiment'] = data['Review'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)  # Convert to string before passing to TextBlob


fig, ax = plt.subplots()
sentiment_counts = data['sentiment'].value_counts()
ax.bar(sentiment_counts.index, sentiment_counts.values)
ax.set_title('Sentiment Analysis Results')
ax.set_xlabel('Sentiment Score')
ax.set_ylabel('Count')
plt.show()
